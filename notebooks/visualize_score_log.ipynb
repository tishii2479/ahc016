# %%
import matplotlib.pyplot as plt

# %%
with open("../data/score_log.txt", "r") as f:
    score_log = f.readline().replace("[", "").replace("]", "").replace(" ", "")

scores = list(map(float, score_log.split(",")))

# %%
plt.plot(scores)
